# %%
import numpy as np
import pandas as pd
import re

def drop_date_rows(df: pd.DataFrame, text_column: str = 'cust_review_text') -> pd.DataFrame:
    """
    Drops rows where the "text" column contains "Date of experience" followed by a date (Month Day, Year).

    Parameters:
        df (pd.DataFrame): DataFrame with 'text' column.
        text_column (str, optional): Name of the text column. Defaults to 'text'.

    Returns:
        pd.DataFrame: The DataFrame with rows containing dates dropped
    """
    date_pattern = re.compile(r'Date of experience:\s*\w+\s*\d{1,2},\s*\d{4}', re.IGNORECASE)
    
    # Identify rows with the date pattern
    matches = df[text_column].apply(lambda text: bool(re.search(date_pattern, text)))
    
    # Invert to select rows that should be kept
    df_filtered = df[~matches]

    return df_filtered


pd.set_option('display.width', None)







df = pd.read_csv('/home/aboveclouds49/project/trustpilot_reviews.csv')

def sample_classes(df, target_column, n_samples):
    # Initialize an empty list to store sampled rows
    sampled_rows = []
    
    # Iterate over each class (1-5)
    for class_value in range(1, 6):
        # Get rows for the current class
        class_rows = df[df[target_column] == class_value]
        
        # Sample min(n_samples, number of rows in the class) rows
        sampled_class_rows = class_rows.sample(n=min(n_samples, len(class_rows)), random_state=42)
        
        # Add the sampled rows to the list
        sampled_rows.append(sampled_class_rows)
    
    # Combine all sampled rows into a single DataFrame
    sampled_df = pd.concat(sampled_rows)
    
    # Return the sampled DataFrame
    return sampled_df

df = sample_classes(df, 'cust_rating', n_samples=5000)[['cust_rating', 'cust_review_text']]
df.dropna(inplace=True)
df = drop_date_rows(df)
df.columns = ['rating', 'text']
df.head()
# Out:
#         rating                                               text
# 138345       1  Terrible! You sent a gate arm that was defecti...
# 8837         1  I would give negative stars if I could. I sent...
# 132569       1  left me with a broken generator on a service p...
# 81850        1  Received an email asking “how did we do?” Orde...
# 47741        1  I recently purchased our first French bulldog ...

# %%
from ner import TextAnalyzer, SentimentAnalysisResults
import os
import warnings

# Force CPU execution
os.environ['CUDA_VISIBLE_DEVICES'] = ''  # Disable GPU visibility
os.environ['OMP_NUM_THREADS'] = '1'  # Limit OpenMP threads
os.environ['MKL_NUM_THREADS'] = '1'  # Limit MKL threads

# Suppress the specific MPS warning
warnings.filterwarnings("ignore", message="UserWarning: Skipping device NVIDIA GeForce GTX 780M that does not support Metal 2.0 (Triggered internally at /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1711403213615/work/aten/src/ATen/mps/MPSDevice.mm:101.)return torch._C._mps_is_available()")

# %%
from ner import TextAnalyzer, SentimentAnalysisResults

analyzer = TextAnalyzer()  # You can specify num_processes if needed
results = await analyzer.train_and_analyze(df, text_column='text', rating_column='rating', batch_size=100)
# Out:
# 2025-01-16 13:40:28,479 - INFO - Starting sentiment analysis pipeline
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.92it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.89it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.77it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.78it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.83it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.76it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.96it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.73it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.72it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.71it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.88it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.89it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.75it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.71it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.90it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.73it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.75it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.88it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.85it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.86it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.86it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.87it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.87it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.89it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.92it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.91it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.89it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.91it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.89it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.87it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.85it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.82it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.85it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:30<00:00,  3.28it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.81it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.88it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.87it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.82it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.79it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.85it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.90it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.90it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.93it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.78it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.88it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.88it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.78it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.90it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.91it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.89it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.91it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:27<00:00,  3.59it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.85it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.85it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.83it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:27<00:00,  3.70it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:27<00:00,  3.60it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:29<00:00,  3.34it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:28<00:00,  3.46it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:44<00:00,  2.25it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:44<00:00,  2.27it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:54<00:00,  1.82it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:50<00:00,  1.98it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:50<00:00,  1.98it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:51<00:00,  1.94it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:49<00:00,  2.02it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:39<00:00,  2.51it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:39<00:00,  2.56it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:48<00:00,  2.07it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:51<00:00,  1.94it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:46<00:00,  2.17it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:51<00:00,  1.95it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:50<00:00,  2.00it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:34<00:00,  2.87it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:34<00:00,  2.90it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:32<00:00,  3.09it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:36<00:00,  2.75it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:37<00:00,  2.64it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:34<00:00,  2.89it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:34<00:00,  2.91it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:36<00:00,  2.73it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:35<00:00,  2.85it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:34<00:00,  2.91it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:34<00:00,  2.88it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:32<00:00,  3.04it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:41<00:00,  2.42it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:39<00:00,  2.53it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:27<00:00,  3.66it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  4.00it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.99it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.99it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.98it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.97it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.97it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.96it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.93it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.96it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.97it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.96it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.97it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.97it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.94it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.98it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.98it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.99it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.94it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.96it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  4.00it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.98it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.97it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:24<00:00,  4.01it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.86it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.99it/s]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.96it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.89it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.96it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.94it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.96it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.96it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.94it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.93it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.91it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.94it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.91it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.87it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:29<00:00,  3.43it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.80it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.91it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.87it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.99it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.94it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.97it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:27<00:00,  3.68it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.84it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:27<00:00,  3.69it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:39<00:00,  2.54it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:31<00:00,  3.18it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.92it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.94it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.93it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.96it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.96it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.96it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:29<00:00,  3.38it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.92it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.90it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.71it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:28<00:00,  3.53it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.94it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.93it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.85it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.84it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.88it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:29<00:00,  3.43it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:32<00:00,  3.09it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:32<00:00,  3.09it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:29<00:00,  3.44it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:26<00:00,  3.80it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:27<00:00,  3.68it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.93it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [00:27<00:00,  3.63it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [01:28<00:00,  1.13it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [02:04<00:00,  1.25s/it]]
# Preprocessing texts: 100%|██████████| 100/100 [02:08<00:00,  1.29s/it]it]
# Preprocessing texts: 100%|██████████| 100/100 [01:10<00:00,  1.43it/s]it]
# Preprocessing texts: 100%|██████████| 100/100 [00:31<00:00,  3.13it/s]it]
# Preprocessing texts: 100%|██████████| 100/100 [00:32<00:00,  3.07it/s]it]
# Preprocessing texts: 100%|██████████| 100/100 [00:35<00:00,  2.86it/s]]
# Preprocessing texts: 100%|██████████| 100/100 [01:57<00:00,  1.18s/it]]
# Preprocessing texts: 100%|██████████| 100/100 [02:16<00:00,  1.36s/it]it]
# Preprocessing texts: 100%|██████████| 100/100 [02:08<00:00,  1.28s/it]it]
# Preprocessing texts: 100%|██████████| 100/100 [02:09<00:00,  1.30s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [02:07<00:00,  1.27s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [01:58<00:00,  1.19s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [01:54<00:00,  1.14s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [02:06<00:00,  1.26s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [02:06<00:00,  1.27s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [02:06<00:00,  1.27s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [02:08<00:00,  1.28s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [02:07<00:00,  1.27s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [02:12<00:00,  1.33s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [02:09<00:00,  1.29s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [01:59<00:00,  1.19s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [01:47<00:00,  1.07s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [01:44<00:00,  1.05s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [02:00<00:00,  1.21s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [01:49<00:00,  1.10s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [01:51<00:00,  1.12s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [01:43<00:00,  1.04s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [01:56<00:00,  1.17s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [01:45<00:00,  1.06s/it]/it]
# Preprocessing texts: 100%|██████████| 100/100 [01:42<00:00,  1.03s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [01:52<00:00,  1.13s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [01:53<00:00,  1.14s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [02:00<00:00,  1.20s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [01:58<00:00,  1.18s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [02:01<00:00,  1.22s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [01:58<00:00,  1.18s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [02:09<00:00,  1.29s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [02:09<00:00,  1.30s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [02:03<00:00,  1.24s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [01:46<00:00,  1.07s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [01:47<00:00,  1.08s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [02:04<00:00,  1.24s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [02:05<00:00,  1.25s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [02:11<00:00,  1.32s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [02:05<00:00,  1.26s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [02:01<00:00,  1.21s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [01:56<00:00,  1.16s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [01:56<00:00,  1.16s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [02:07<00:00,  1.27s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [02:06<00:00,  1.26s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [02:03<00:00,  1.23s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [02:06<00:00,  1.27s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [01:57<00:00,  1.17s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [01:50<00:00,  1.10s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [01:54<00:00,  1.15s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [01:54<00:00,  1.15s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [01:55<00:00,  1.16s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [01:43<00:00,  1.03s/it]t]
# Preprocessing texts: 100%|██████████| 100/100 [01:32<00:00,  1.08it/s]t]
# Preprocessing texts: 100%|██████████| 52/52 [00:38<00:00,  1.36it/s]/it]
# Processing batches: 100%|██████████| 240/240 [3:24:08<00:00, 51.04s/it]
# 2025-01-16 17:04:37,399 - INFO - Vectorizing texts...
# 2025-01-16 17:04:50,460 - INFO - Training model...
# /home/aboveclouds49/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 2025-01-16 17:04:57,767 - INFO -
# Classification Report:
# 2025-01-16 17:04:57,818 - INFO -
#               precision    recall  f1-score   support
#
#            1       0.18      0.18      0.18       965
#            2       0.21      0.22      0.22       976
#            3       0.22      0.23      0.22       971
#            4       0.18      0.15      0.16       896
#            5       0.21      0.22      0.22       983
#
#     accuracy                           0.20      4791
#    macro avg       0.20      0.20      0.20      4791
# weighted avg       0.20      0.20      0.20      4791
#
# 2025-01-16 17:04:57,826 - INFO -
# Top predictive features:
# 2025-01-16 17:04:57,827 - INFO - complaint: 0.9360
# 2025-01-16 17:04:57,828 - INFO - spot: 0.7828
# 2025-01-16 17:04:57,829 - INFO - rep: 0.7808
# 2025-01-16 17:04:57,830 - INFO - furniture: 0.7240
# 2025-01-16 17:04:57,831 - INFO - tank: 0.7070
# 2025-01-16 17:04:57,832 - INFO - text: 0.7030
# 2025-01-16 17:04:57,832 - INFO - up: 0.6999
# 2025-01-16 17:04:57,833 - INFO - risk: 0.6985
# 2025-01-16 17:04:57,834 - INFO - diamond: 0.6880
# 2025-01-16 17:04:57,835 - INFO - drill: 0.6846

# %%
print("Classification Report:\n", results.classification_report)
print("\nConfusion Matrix:\n", results.confusion_matrix)
print("\nFeature Importance (Top 10):\n", list(results.feature_importance.items())[:10])
print("\nRating Distribution:\n", results.rating_distribution)
print("\nText Length Statistics:\n", results.text_length_stats)
print("\nSentiment by Length:\n", results.sentiment_by_length)

# To access the predictions and probabilities:
predictions = results.predictions
probabilities = results.probabilities
# Out:
# Classification Report:
#  {'1': {'precision': 0.17611336032388664, 'recall': 0.18031088082901556, 'f1-score': 0.1781874039938556, 'support': 965.0}, '2': {'precision': 0.21226874391431352, 'recall': 0.22336065573770492, 'f1-score': 0.21767348976535197, 'support': 976.0}, '3': {'precision': 0.22111553784860558, 'recall': 0.2286302780638517, 'f1-score': 0.22481012658227847, 'support': 971.0}, '4': {'precision': 0.18157181571815717, 'recall': 0.14955357142857142, 'f1-score': 0.16401468788249693, 'support': 896.0}, '5': {'precision': 0.21083172147001933, 'recall': 0.22177009155645983, 'f1-score': 0.21616261774913237, 'support': 983.0}, 'accuracy': 0.2016280525986224, 'macro avg': {'precision': 0.20038023585499648, 'recall': 0.2007250955231207, 'f1-score': 0.20016966519462306, 'support': 4791.0}, 'weighted avg': {'precision': 0.20074364498276237, 'recall': 0.2016280525986224, 'f1-score': 0.20082150226811957, 'support': 4791.0}}
#
# Confusion Matrix:
#  [[174 201 208 177 205]
#  [224 218 205 118 211]
#  [202 205 222 131 211]
#  [181 211 181 134 189]
#  [207 192 188 178 218]]
#
# Feature Importance (Top 10):
#  [('complaint', 0.9359764208588425), ('spot', 0.7827873150164425), ('rep', 0.780807435962543), ('furniture', 0.7240492491700429), ('tank', 0.7070023075211945), ('text', 0.7030188691214573), ('up', 0.699922791559393), ('risk', 0.6984828249649857), ('diamond', 0.6880206780116205), ('drill', 0.6846405469071806)]
#
# Rating Distribution:
#  Counter({5: 4915, 2: 4880, 3: 4852, 1: 4824, 4: 4481})
#
# Text Length Statistics:
#  {'mean_length': 25.562082498329993, 'median_length': 19.0, 'std_length': 26.503397838752793, 'length_by_rating': {1: 32.73776948590381, 2: 30.2327868852459, 3: 24.916117065127782, 4: 21.252845347020756, 5: 18.44821973550356}}
#
# Sentiment by Length:
#  {'uniform_length': {1: 1.0}, 'very_long': {1: 0.28403100775193796, 2: 0.2607751937984496, 3: 0.19193798449612404, 4: 0.13705426356589148, 5: 0.1262015503875969}, 'very_short': {1: 0.18152542372881356, 2: 0.1740677966101695, 3: 0.20355932203389832, 4: 0.18423728813559323, 5: 0.25661016949152543}, 'short': {1: 0.1649782923299566, 2: 0.17655571635311143, 3: 0.19916787264833574, 4: 0.22955861070911723, 5: 0.229739507959479}, 'long': {1: 0.22784810126582278, 2: 0.23176064441887226, 3: 0.20092059838895282, 4: 0.16823935558112774, 5: 0.1712313003452244}, 'medium': {1: 0.18857258227336968, 2: 0.20775287704421563, 3: 0.21360791439531596, 4: 0.19220674338784574, 5: 0.19785988289925296}}
